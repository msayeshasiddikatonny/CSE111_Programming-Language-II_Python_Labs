# %% [markdown]
# <a href="https://colab.research.google.com/github/msayeshasiddikatonny/CSE111_Python/blob/main/CSE111_Assignment_04_Fall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Solve of Question 1

class Calculator:
    def __init__(self,first_value,operator,second_value):
        self.first_value = first_value
        self.operator = operator
        self.second_value = second_value
    print("Let’s Calculate!")
        
    def add(self):
        print("Result: ", first_value + second_value)
    def subtract(self):
        print("Result: ", first_value - second_value)
    def multiply(self):
        print("Result: ", first_value * second_value)
    def divide(self):
        print("Result: ", first_value / second_value)

first_value = int(input("Value 1: "))
operator = input("Operator: ")
second_value = int(input("Value 2: "))

vab = Calculator(first_value, operator, second_value)

if operator == "+":
    vab.add()
elif operator == "-": 
    vab.subtract()
elif operator == "*":
    vab.multiply()
else:
    vab.divide()
# Out:
# Let’s Calculate!
# Value 1: 5
# Operator: *
# Value 2: 6
# Result:  30

# %%
#Solve of Question 2

class Customer:
    def __init__(self,name):
        self.name = name

    def greet(self,var = None):
        if var != None:
            print("Hello",var+"!")
        else:
            print("Hello!")
        
    def purchase(self,*var):
        print(f"{self.name}, you purchased {len(var)} item(s):")
        
        for x in var:
            print(x)
        
customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchased 3 item(s):
# chips
# chocolate
# orange juice
# -------------------
# Hello David!
# David, you purchased 1 item(s):
# orange juice

# %%
#Solve of Question 3

class Panda:
    def __init__(self,name,gender,age):
        self.name = name
        self.gender = gender
        self.age = age

    def sleep(self,sleep = ""):
        if sleep != "":
            if 3 <= sleep <= 5:
                return(f"{self.name} sleeps {sleep} hours daily and should have Mixed Veggies")
            elif 6 <= sleep <= 8:
                return(f"{self.name} sleeps {sleep} hours daily and should have Eggplant & Tofu")
            elif 9 <= sleep <= 11:
                return(f"{self.name} sleeps {sleep} hours daily and should have Broccoli Chicken")
        else:
            return(f"{self.name}'s duration is unknown thus should have only bamboo leaves")    

panda1 = Panda("Kunfu","Male", 5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)
print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %%
#Solve of Question 4

class Cat:
    def __init__(self,color = "",doing = ""):
        self.color = color
        self.doing = doing

    def printCat(self):
        if self.color == "" and self.doing == "":
            print('White cat is sitting')
        elif self.color != "" and self.doing == "":
            print(f"{self.color} cat is sitting")
        elif self.color != "" and self.doing != "":
            print(f"{self.color} cat is {self.doing}")
    def changeColor(self,cc):
        self.color = cc

c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#Solve of Question 5

class Student:
    def __init__(self,name = ""):
        self.name = name
        self.average = 0
        if self.name == "":
            self.name = "default student"

    def quizcalc(self,m1,m2=0,m3=0):
        self.average = (m1 + m2 + m3) / 3

    def printdetail(self):
        print("Hello", self.name)
        print("Your average quiz score is", self.average)
        
s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello default student
# Your average quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666

# %%
#Solve of Question 6

class Vehicle:
    def __init__(self):
        self.x = 0
        self.y = 0

    def moveUp(self):
        self.x = 0
        self.y = 1

    def moveLeft(self):
        self.x = -1
        self.y = 1 

    def moveDown(self):
        self.x = -1
        self.y = 0

    def moveRight(self):
        self.x = 0
        self.y = 0
        
    def print_position(self):
        print(f"({self.x},{self.y})")    

car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0,0)
# (0,1)
# (-1,1)
# (-1,0)

# %%
#Solve of Question 7

class Programmer:
    def __init__(self,name,language,experience):
        self.name = name
        self.language = language
        self.experience = experience
        print("Horray! A new programmer is born")

    def addExp(self,exper):
        print(f"Updating experience of {self.name}")
        self.experience = self.experience + exper

    def printDetails(self):
      print(f"Name: { self.name}\nLanguage: { self.language}\nExperience: { self.experience} years.")

p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10 years.
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7 years.
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4 years.
# Updating experience of Jon Snow
# Name: Jon Snow
# Language: Python
# Experience: 9 years.

# %%
#Solve of Question 8

class Student:
    def __init__(self,name,id,depart = "CSE"):
        self.name = name
        self.id = id
        self.depart = depart
    def dailyEffort(self,time):
        self.time = time    

    def printDetails(self):
        print(f"Name: {self.name}\nID: {self.id}\nDepartment: {self.depart}")
        print(f"Daily Effort: {self.time} hour(s)")

        if self.time <= 2:
            print("Suggestion: Should give more effort!")
        elif self.time <= 4:
            print("Suggestion: Keep up the good work!")
        else:
            print("Suggestion: Excellent! Now motivate others.")    

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent! Now motivate others.

# %%
#Solve of Question 9

class Patient:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def add_Symptom(self,*arg):
        self.symptom = arg

    def printPatientDetail(self):
        print(f"Name: {self.name}\nAge: {self.age}\nSymptoms:",end=" ")

        for x in self.symptom:
            if self.symptom.index(x) == len(self.symptom)-1:
                print(x)
            else:
                print(x,end=", ")
    
p1 = Patient('Thomas', 23)
p1.add_Symptom('Headache')
p2 = Patient('Carol', 20)
p2.add_Symptom('Vomiting', 'Coughing')
p3 = Patient('Mike', 25)
p3.add_Symptom('Fever', 'Headache', 'Coughing')
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
print("=========================")
# Out:
# ...
# Name: Thomas
# Age: 23
# Symptoms: Headache
# ...
# Name: Carol
# Age: 20
# Symptoms: Vomiting, Coughing
# ...
# Name: Mike
# Age: 25
# Symptoms: Fever, Headache, Coughing
# ...

# %%
#Solve of Question 10

class Avengers:
    def __init__(self,name,partner):
        self.name = name
        self.partner = partner
    def super_powers(self,*arg):
        self.super_powers = arg
    def printAvengersDetail(self):
      print(f"Name: {self.name}\nPartner: {self.partner}\nSuper powers: ",end="")
      for x in self.super_powers:
        if self.super_powers.index(x) == len(self.super_powers)-1:
            print(x)
        else:
            print(x,end=", ")

a1 = Avengers('Captain America', 'Bucky Barnes')
a1.super_powers('Stamina', 'Slowed ageing')
a2 = Avengers('Doctor Strange', 'Ancient One')
a2.super_powers('Mastery of magic')
a3 = Avengers('Iron Man', 'War Machine')
a3.super_powers('Genius level intellect', 'Scientist ')
print("=========================")
a1.printAvengersDetail()
print("=========================")
a2.printAvengersDetail()
print("=========================")
a3.printAvengersDetail()
print("=========================")
# Out:
# ...
# Name: Captain America
# Partner: Bucky Barnes
# Super powers: Stamina, Slowed ageing
# ...
# Name: Doctor Strange
# Partner: Ancient One
# Super powers: Mastery of magic
# ...
# Name: Iron Man
# Partner: War Machine
# Super powers: Genius level intellect, Scientist
# ...

# %%
#Solve of Question 11

class Shinobi:
    def __init__(self,name,rank,mission_num="0",salary="0"):
        self.name = name
        self.rank = rank
        self.mission_num =  mission_num
        self.salary = salary

    def changeRank(self,var):
        self.rank = var

    def calSalary(self,cou):
        self.mission_num = cou
        if self.rank == "Genin":
            self.salary = self.mission_num*50
        elif self.rank == "Chunin":
            self.salary = self.mission_num*100    
        else:
            self.salary=self.mission_num*500
    def printInfo(self):
        print(f"Name: {self.name}\nRank: {self.rank}\nNumber of mission: {self.mission_num}\nSalary: {self.salary}")
     
naruto = Shinobi("Naruto","Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru',"Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary: 250
# ...
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary: 0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary: 1000
# ...
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary: 2500

# %%
#Solve of Question 12

class ParcelKoro:
    def __init__(self,cus_name = "No name set",pro_weight = 0):
        self.cus_name = cus_name
        self.pro_weight = pro_weight

    def calculateFee(self,loc_charge = ""):
        if self.pro_weight == 0:
            self.total_fee = 0
        elif self.pro_weight != 0 and loc_charge != "":
            self.total_fee = (self.pro_weight * 20) + 100
        elif self.pro_weight != 0 and loc_charge == "":
            self.total_fee = (self.pro_weight * 20) + 50

    def printDetails(self):
        print(f"Customer Name: {self.cus_name}\nProduct Weight: {self.pro_weight}\nTotal fee: {self.total_fee}")

print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.pro_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#Solve of Question 13

class Batsman:
    def __init__(self,*arg):
        if len(arg) == 2:
            self.name = "New Batsman"
            self.runsScored = arg[0]
            self.ballsFaced = arg[1]
        else:
            self.name = arg[0]
            self.runsScored = arg[1]
            self.ballsFaced = arg[2]
    def setName(self,new):
        self.name = new
    def battingStrikeRate(self):
        final = (self.runsScored / self.ballsFaced) * 100
        return final
  
    def printCareerStatistics(self):
        print(f"Name: {self.name}\nRuns Scored: {self.runsScored}, Balls Faced: {self.ballsFaced}")

b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101, Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678, Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101, Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#Solve of Question 14

class EPL_Team:
    def __init__(self,*var):
        if len(var) == 2:
            self.name = var[0]
            self.song = var[1]
            self.total_title_no = "0"
        else:
            self.name = var[0]
            self.song = "No Slogan"
            self.total_title_no = "0"
          
    def increaseTitle(self,new = "1"):
        self.total_title_no = new
    def changeSong(self,changedsong):
        self.song = changedsong
    def showClubInfo(self):
        return(f"Name: {self.name}\nSong: {self.song}\nTotal No of title: {self.total_title_no}")

manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 0
# ##################
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title: 1
# ...
# Name: Chelsea
# Song: No Slogan
# Total No of title: 0
# Name: Chelsea
# Song: Keep the blue flag flying high
# Total No of title: 0

# %%
#Solve of Question 15

class Account:
    def __init__(self,*var):
        if len(var)==0:
            self.name="Default Account"
            self.balance=0
        elif len(var)==1:
            self.name=var[0]
            self.balance=0
        else:
            self.name=var[0]
            self.balance=var[1]

    def details(self):
            return(f"{self.name}\n{float(self.balance)}")
    def withdraw(self,amount):
        if self.balance-amount<=3070:
            print("Sorry, Withdraw unsuccessful! The account\nbalance after deducting"+
                  " withdraw amount is\nequal to or less than minimum.")
        else:   
            self.balance-=amount
            print(f"Withdraw successful! New balance is: {float(self.balance)}")

a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance =10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930);
print("------------------------")
a2.withdraw(600);
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400.0
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#Sol:15
class Account:
    def __init__(self,name="Default Account",money=0):
        self.name=name
        self.balance=float(money)

    def withdraw(self,withdraw):
        total_amount=self.balance-withdraw
        if total_amount <=3070:
            print("Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.")
        else:
            print(f'Withdraw successful! New balance is:{total_amount}')

    def details(self):
        return f"{self.name}\n{self.balance}"

a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930);
print("------------------------")
a2.withdraw(600);
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400.0
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is:3071.0

# %%
#Solve of Question 16

class Author:
    def __init__(self,name = "Default",*var):
        self.name = name
        self.book = list(var)

    def addBooks(self,*add_books):
        self.book += list(add_books)

    def changeName(self,change_name):
        self.name = change_name

    def printDetails(self): 
        print(f"Author Name: {self.name}\n--------\nList of Books:")
        
        for x in self.book:
            print(x)

auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#Sol:16
class Author:
    def __init__(self,name='Default',*arg):
        self.name=name
        self.arg=arg
    def addBooks(self,*arg):
        self.arg=arg
    def changeName(self,change_name):
        self.name=change_name
    def printDetails(self):
        print(f'Author Name:{self.name}\n-------\nList of Books:')
        for index in self.arg:
            print(index)


auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print('===================')
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print('===================')
auth2.printDetails()
print('===================')
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name:Humayun Ahmed
# -------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name:Mario Puzo
# -------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name:Paolo Coelho
# -------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#Task 17

class Student:
    def __init__(self,name= " ",dept=" "):
        self.name = name
        self.dept = dept
        if self.name == " " and self.dept == " ":
            print("Student name and department need to be set")
        elif self.name != " " and self.dept ==" ":
            print("Department for Carol needs to be set")
        else:
            print(self.name,"is from EEE department")
        
    def update_name(self,x):
        self.name = x
        
    def update_department(self,d):
        self.dept = d
    
    
    def enroll(self,*a):
        self.course = a
        
    def printDetail(self):
        print("Name:",self.name)
        print("Department:",self.dept)
        print("Bob enrolled in",len(self.course),"course(s):")
        for i in self.course:
            print(i)
            


s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name: Bob
# Department: CSE
# Bob enrolled in 3 course(s):
# CSE110
# MAT110
# ENG091
# ...
# Name: Carol
# Department: BBA
# Bob enrolled in 1 course(s):
# BUS101
# ...
# Name: Jon
# Department: EEE
# Bob enrolled in 2 course(s):
# MAT110
# PHY111

# %%
#18

class Student:
    def __init__(self, name = None, student_id = None, dpt = None):
        self.name = name
        self.student_id = student_id
        self.dpt = dpt
        self.courses = None

    def details(self):
        return f"Name: {self.name}\nID: {self.student_id}\nDepartment: {self.dpt}"

    def advise(self, *courses):
        self.courses = courses
        credit = len(courses) * 3.0

        print(f"{self.name}, you have taken {credit} credits.")

        print(f"List of courses: {self.courses[0]}", end = "")
        for course in self.courses[1:]:
            print(",", course, end = "")
        print()

        status = None
        if (credit >= 9.0) and (credit <= 12.0):
            status = "Ok"
        elif credit < 9.0:
            status = f"You have to take at least {3-len(self.courses)} more course."
        else:
            status = f"You have to drop at least {len(self.courses)-4} course."

        print(f"Status: {status}")


if __name__ == "__main__":
    s1 = Student("Alice", "20103012", "CSE")
    s2 = Student("Bob", "18301254", "EEE")
    s3 = Student("Carol", "17101238", "CSE")
    print("##########################")
    print(s1.details())
    print("##########################")
    print(s2.details())
    print("##########################")
    s1.advise("CSE110", "MAT110", "PHY111")
    print("##########################")
    s2.advise("BUS101", "MAT120")
    print("##########################")
    s3.advise("MAT110", "PHY111", "ENG102", "CSE111", "CSE230")
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice, you have taken 9.0 credits.
# List of courses: CSE110, MAT110, PHY111
# Status: Ok
# ##########################
# Bob, you have taken 6.0 credits.
# List of courses: BUS101, MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Carol, you have taken 15.0 credits.
# List of courses: MAT110, PHY111, ENG102, CSE111, CSE230
# Status: You have to drop at least 1 course.

# %%
#19

class Hotel:
    guests = {}
    current_guest_id = 1
    staffs = {}
    current_staff_id = 1

    def __init__(self, *info):
        if len(info) == 4:
            self.guest_name = info[1]
            self.guest_age = info[2]
            self.guest_phone = info[3]
            self.guest_id = None

            self.addGuest(self.guest_name, self.guest_age, self.guest_phone)
        else:
            self.staff_name = None
            self.staff_age = None
            self.staff_phone = None
            self.staff_id = None

    def addStuff(self, name, age, phone = "000"):
        self.staff_name = name
        self.staff_age = age
        self.staff_phone = phone
        self.staff_id = Hotel.current_staff_id
        print(f"Staff With ID {self.staff_id} is added")
        Hotel.current_staff_id += 1

        self.staffs[self.staff_id] = [self.staff_name, self.staff_age, self.staff_phone]

    def addGuest(self, name, age, phone):
        self.guest_name = name
        self.guest_age = age
        self.guest_phone = phone
        self.guest_id = Hotel.current_guest_id
        print(f"Guest With ID {self.guest_id} is added")
        Hotel.current_guest_id += 1

        self.guests[self.guest_id] = [self.guest_name, self.guest_age, self.guest_phone]

    def getStuffById(self, staff_id):
        return f"Staff ID: {staff_id}\nName: {self.staffs[staff_id][0]}\nAge: {self.staffs[staff_id][1]}\nPhone no.: {self.staffs[staff_id][2]}"

    def getGuestById(self, guest_id):
        return f"Guest ID: {guest_id}\nName: {self.guests[guest_id][0]}\nAge: {self.guests[guest_id][1]}\nPhone no.: {self.guests[guest_id][2]}"

    def getDetails(self):
        return self.getGuestById(self.guest_id)

    def allStaffs(self):
        print("All Staffs:")
        print("Number of Staff:", len(Hotel.staffs.keys()))
        for staff_id, info in Hotel.staffs.items():
            print(f"Staff ID: {staff_id} Name: {info[0]} Age: {info[1]} Phone no: {info[2]}")

    def allGuest(self):
        print("All Guests:")
        print("Number of Guest:", len(Hotel.guests.keys()))
        for guest_id, info in Hotel.guests.items():
            print(f"Guest ID: {guest_id} Name: {info[0]} Age: {info[1]} Phone no: {info[2]}")


if __name__ == "__main__":
    s1 = Hotel()
    g1 = Hotel()


    h = Hotel("Lakeshore")
    h.addStuff("Adam", 26)
    print("=================================")
    print(h.getStuffById(1))
    print("=================================")
    h.addGuest("Carol", 35,"123")
    print("=================================")
    print(h.getGuestById(1))
    print("=================================")
    g2 = Hotel("Guest", "Diana", 32, "431")
    print("=================================")
    print(g2.getDetails())
    print("=================================")
    s1.allStaffs()
    print("=================================")
    g1.allGuest()
# Out:
# Staff With ID 1 is added
# ...
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.: 000
# ...
# Guest With ID 1 is added
# ...
# Guest ID: 1
# Name: Carol
# Age: 35
# Phone no.: 123
# ...
# Guest With ID 2 is added
# ...
# Guest ID: 2
# Name: Diana
# Age: 32
# Phone no.: 431
# ...
# All Staffs:
# Number of Staff: 1
# Staff ID: 1 Name: Adam Age: 26 Phone no: 000
# ...
# All Guests:
# Number of Guest: 2
# Guest ID: 1 Name: Carol Age: 35 Phone no: 123
# Guest ID: 2 Name: Diana Age: 32 Phone no: 431

# %%
#20

class Author:
    def __init__(self, name = None):
        self.name = name
        self.books = {}

    def addBook(self, *book_info):
        if self.name == None:
            print("A book can not be added without author name")
        else:
            if book_info[1] in self.books.keys():
                self.books[book_info[1]].append(book_info[0])
            else:
                self.books.update({book_info[1]: [book_info[0]]})

    def setName(self, new_name):
        self.name = new_name

    def printDetail(self):
        number_of_books = 0
        for category in self.books.keys():
            number_of_books += len(self.books[category])

        print("Number of Book(s):", number_of_books)

        print(f"Author Name: {self.name}")

        for category, books in self.books.items():
            print(f"{category}: {books[0]}", end = "")

            for book in books[1:]:
                print(",", book, end = "")

            print()


if __name__ == "__main__":
    a1 = Author()
    print("=================================")
    a1.addBook("Ice", "Science Fiction")
    print("=================================")
    a1.setName("Anna Kavan")
    a1.addBook("Ice", "Science Fiction")
    a1.printDetail()
    print("=================================")
    a2 = Author("Humayun Ahmed")
    a2.addBook("Onnobhubon", "Science Fiction")
    a2.addBook("Megher Upor Bari", "Horror")
    print("=================================")
    a2.printDetail()
    a2.addBook("Ireena", "Science Fiction")
    print("=================================")
    a2.printDetail()
    print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# ...

# %%
#21

class Hospital:
    doctors = {}
    patients = {}

    def __init__(self, *info):
        if len(info) == 3:
            self.name = info[1]
            self.speciality = info[2]
            self.doctor_id = None
        else:
            self.name = info[1]
            self.age = info[2]
            self.phone = info[3]
            self.patient_id = None

    def addDoctor(self, doctor_id):
        self.doctor_id = doctor_id

        self.doctors[self.doctor_id] = [self.name, self.speciality]

    def addPatient(self, patient_id):
        self.patient_id = patient_id

        self.patients[self.patient_id] = [self.name, self.age, self.phone]

    def getDoctorByID(self, doctor_id):
        return f"Doctor's ID: {doctor_id}\nName: {self.doctors[doctor_id][0]}\nSpeciality: {self.doctors[doctor_id][1]}"

    def getPatientByID(self, patient_id):
        return f"Patient's ID: {patient_id}\nName: {self.patients[patient_id][0]}\nAge: {self.patients[patient_id][1]}\nPhone no.: {self.patients[patient_id][2]}"

    def allDoctors(self):
        print("All Doctors:")
        print("Number of Doctors:", len(self.doctors.keys()))
        print(self.doctors)

    def allPatients(self):
        print("All Patients:")
        print("Number of Patients:", len(self.patients.keys()))
        print(self.patients)


if __name__ == "__main__":
    d1 = Hospital("Doctor", "Samar Kumar", "Neurologist")
    d1.addDoctor("1d")
    print(d1.getDoctorByID("1d"))
    print("=================================")
    p1 = Hospital("Patient", "Kashem Ahmed", 35, 12345)
    p1.addPatient("1p")
    print(d1.getPatientByID("1p"))
    print("=================================")
    p2 = Hospital("Patient", "Tanina Haque", 26, 33456)
    p2.addPatient("2p")
    print(d1.getPatientByID("2p"))
    print("=================================")
    d1.allDoctors()
    p1.allPatients()
# Out:
# Doctor's ID: 1d
# Name: Samar Kumar
# Speciality: Neurologist
# ...
# Patient's ID: 1p
# Name: Kashem Ahmed
# Age: 35
# Phone no.: 12345
# ...
# Patient's ID: 2p
# Name: Tanina Haque
# Age: 26
# Phone no.: 33456
# ...
# All Doctors:
# Number of Doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Number of Patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}

# %%
#22

class Vaccine:
    def __init__(self, name, origin, frequency):
        self.name = name
        self.origin = origin
        self.frequency = frequency

    def compare(self, other):
        if self.name == other.name:
            return True
        else:
            return False


class Person:
    def __init__(self, name, age, type = "General Citizen"):
        self.name = name
        self.age = age
        self.type = type
        self.vaccine = None
        self.first_dose = None
        self.second_dose = None

    def pushVaccine(self, pushing_vaccine, dose = "1st Dose"):
        if self.type == "Student" or self.age >= 25:
            if self.vaccine == None:
                self.vaccine = pushing_vaccine
                self.first_dose = "Given"
                self.second_dose = f"Please come after {self.vaccine.frequency} days"

                print(f"1st dose done for {self.name}")
            else:
                if self.vaccine.compare(pushing_vaccine):
                    self.second_dose = "Given"

                    print(f"2nd dose done for {self.name}")
                else:
                    print(f"Sorry {self.name}, you can’t take 2 different vaccines")
        else:
            print(f"Sorry {self.name}, Minimum age for taking vaccines is 25 years now.")

    def showDetail(self):
        print(f"Name: {self.name} Age: {self.age} Type: {self.type}")
        print(f"Vaccine name: {self.vaccine.name}")
        print(f"1st dose: {self.first_dose}")
        print(f"2nd dose: {self.second_dose}")


if __name__ == "__main__":
    astra = Vaccine("AstraZeneca", "UK", 60)
    modr = Vaccine("Moderna", "UK", 30)
    sin = Vaccine("Sinopharm", "China", 30)
    p1 = Person("Bob", 21, "Student")
    print("=================================")
    p1.pushVaccine(astra)
    print("=================================")
    p1.showDetail()
    print("=================================")
    p1.pushVaccine(sin, "2nd Dose")
    print("=================================")
    p1.pushVaccine(astra, "2nd Dose")
    print("=================================")
    p1.showDetail()
    print("=================================")
    p2 = Person("Carol", 23, "Actor")
    print("=================================")
    p2.pushVaccine(sin)
    print("=================================")
    p3 = Person("David", 34)
    print("=================================")
    p3.pushVaccine(modr)
    print("=================================")
    p3.showDetail()
    print("=================================")
    p3.pushVaccine(modr, "2nd Dose")
# Out:
# ...
# 1st dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Please come after 60 days
# ...
# Sorry Bob, you can’t take 2 different vaccines
# ...
# 2nd dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Given
# ...
# Sorry Carol, Minimum age for taking vaccines is 25 years now.
# ...
# 1st dose done for David
# ...
# Name: David Age: 34 Type: General Citizen
# Vaccine name: Moderna
# 1st dose: Given
# 2nd dose: Please come after 30 days
# ...
# 2nd dose done for David
