# %% [markdown]
# <a href="https://colab.research.google.com/github/msayeshasiddikatonny/CSE111_Python/blob/main/CSE111_Assessment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 𝗤𝘂𝗲𝘀𝘁𝗶𝗼𝗻:
# Implement the design of the Smartphone class so that the following output is produced:
#
# # Write your code here
#
# print(“No.of Smartphone =”, Smartphone.count)\
# s1 = Smartphone('Oneplus 9 Pro', 2021)\
# s1.add_Features(‘Snapdragon 888’ , ‘Wireless Charging’, ‘Hasselblad Camera’)\
# s2 = Smartphone('Samsung Galaxy S21', 2020)\
# s2.add_Features(‘Exynos 2100’ , ‘Fast charging 25W’)\
# s3 = Smartphone('MI 11 Ultra', 2021)\
# s3.add_Features(‘Fast charging 67W’ ,  Snapdragon 888’)\
# print("=========================")\
# s1.printPhoneDetail()\
# print("=========================")\
# s2.printPhoneDetail()\
# print("=========================")\
# s3.printPhoneDetail()\
# print("=========================")\
# print(“No.of Smartphone =”,Smartphone.count)
#
# Output:
# No.of Smartphone = 0\
# =========================\
# Model Name: Oneplus 9 Pro\
# Year of release: 2021\
# Features: Snapdragon 888, Wireless Charging, Hasselblad Camera\
# =========================\
# Model Name: Samsung Galaxy S21\
# Year of release: 2020\
# Features: Exynos 2100, Fast charging 25W\
# =========================\
# Model Name: MI 11 Ultra\
# Year of release: 2021\
# Features: Fast charging 67W,  Snapdragon 888\
# =========================\
# No.of Smartphone = 3

# %%
class Smartphone:
  count = 0
  def __init__(self, name, year):
    self.name = name
    self.year = year
    self.feature = []
    Smartphone.count += 1
  def add_Features(self, *args):
    for x in args:
     self.feature.append(x)
  def printPhoneDetail(self):
    print(f"Model Name: {self.name}")
    print(f"Year of release: {self.year}")
    print(f"Features: ", end = "")
    print(self.feature[0], end = "")
    for i in range(1, len(self.feature)):
     print(", " + self.feature[i], end = "")
    print()

print("No.of Smartphone =", Smartphone.count)
s1 = Smartphone('Oneplus 9 Pro', 2021)
s1.add_Features('Snapdragon 888' , 'Wireless Charging', 'Hasselblad Camera')
s2 = Smartphone('Samsung Galaxy S21', 2020)
s2.add_Features('Exynos 2100' , 'Fast charging 25W')
s3 = Smartphone('MI 11 Ultra', 2021)
s3.add_Features('Fast charging 67W' , 'Snapdragon 888')
print("=========================")
s1.printPhoneDetail()
print("=========================")
s2.printPhoneDetail()
print("=========================")
s3.printPhoneDetail()
print("=========================")
print("No.of Smartphone =",Smartphone.count)
# Out:
# No.of Smartphone = 0
# ...
# Model Name: Oneplus 9 Pro
# Year of release: 2021
# Features: Snapdragon 888, Wireless Charging, Hasselblad Camera
# ...
# Model Name: Samsung Galaxy S21
# Year of release: 2020
# Features: Exynos 2100, Fast charging 25W
# ...
# Model Name: MI 11 Ultra
# Year of release: 2021
# Features: Fast charging 67W, Snapdragon 888
# ...
# No.of Smartphone = 3

# %% [markdown]
# 𝗤𝘂𝗲𝘀𝘁𝗶𝗼𝗻:
# Suppose you are an owner of a car wash & service center. Now, implement the design of the Car class so that the following output is produced:
#
# # Write your codes here.
#
# # Do not change the following lines of code.
# print(“No.of Car=”, Car.count)\
# c1 = Car('Lamborghini', 2002)\
# c1.add_Services('Battery Replacement', 'A/C Recharge')\
# c2 = Car('Toyota Corolla', 2016)\
# c2.add_Services('Radiator Flush', 'Fill Service')\
# c3 = Car('Mitsubishi Pajero', 2018)\
# c3.add_Services('Filter change', 'Timing Belt Replacement')\
# print("=========================")\
# c1.printCarDetail()\
# print("=========================")\
# c2.printCarDetail()\
# print("=========================")\
# c3.printCarDetail()\
# print("=========================")\
# print(“No.of Car =”, Car.count)\
#
# Output:
# No.of Car = 0\
# =========================\
# Name: Lamborghini\
# Year of manufacture: 2002\
# List of Services: Battery Replacement , A/C Recharge\
# =========================\
# Name: Toyota Corolla\
# Year of manufacture: 2016\
# List of Services: Radiator Flush , Fill Service\
# =========================\
# Name: Mitsubishi Pajero\
# Year of manufacture: 2018\
# List of Services: Filter change , Timing Belt Replacement\
# =========================\
# No.of Car = 3

# %%
class Car:
    count = 0
    def __init__(self, name, manufacture_year):
        self.name = name
        self.manufacture_year = manufacture_year
        self.services = []
        Car.count += 1

    def add_Services(self, *services):
        self.services += services
    
    def printCarDetail(self):
        print("Name:", self.name)
        print("Year of manufacture:", self.manufacture_year)
        print("List of Services: ", end = '')
        sep = ''
        for service in self.services:
            print(sep + service, end = '')
            sep = ', '
        print()
 
# Do not change the following lines of code.
print("No.of Car=", Car.count)
c1 = Car('Lamborghini', 2002)
c1.add_Services('Battery Replacement', 'A/C Recharge')
c2 = Car('Toyota Corolla', 2016)
c2.add_Services('Radiator Flush', 'Fill Service')
c3 = Car('Mitsubishi Pajero', 2018)
c3.add_Services('Filter change', 'Timing Belt Replacement')
print("=========================")
c1.printCarDetail()
print("=========================")
c2.printCarDetail()
print("=========================")
c3.printCarDetail()
print("=========================")
print("No.of Car =", Car.count)

# %%
class Car:
    count = 0
    def __init__(self, name, manufacture_year):
        self.name = name
        self.manufacture_year = manufacture_year
         

    def add_Services(self, a,b):
        self.service1=a
        self.service2=b
    def printCarDetail(self):
        print("Name:", self.name)
        print("Year of manufacture:", self.manufacture_year)
        print("List of Services: ",  self.service1,",", self.service2)
         
 
# Do not change the following lines of code.
print("No.of Car=", Car.count)
c1 = Car('Lamborghini', 2002)
c1.add_Services('Battery Replacement', 'A/C Recharge')
c2 = Car('Toyota Corolla', 2016)
c2.add_Services('Radiator Flush', 'Fill Service')
c3 = Car('Mitsubishi Pajero', 2018)
c3.add_Services('Filter change', 'Timing Belt Replacement')
print("=========================")
c1.printCarDetail()
print("=========================")
c2.printCarDetail()
print("=========================")
c3.printCarDetail()
print("=========================")
print("No.of Car =", Car.count)
# Out:
# No.of Car= 0
# ...
# Name: Lamborghini
# Year of manufacture: 2002
# List of Services:  Battery Replacement , A/C Recharge
# ...
# Name: Toyota Corolla
# Year of manufacture: 2016
# List of Services:  Radiator Flush , Fill Service
# ...
# Name: Mitsubishi Pajero
# Year of manufacture: 2018
# List of Services:  Filter change , Timing Belt Replacement
# ...
# No.of Car = 0

# %%
class Car:
  count = 0
  def __init__(self, name, year):
    self.name = name
    self.year = year
    Car.count+=1
  def add_Services(self, condition, service):
    self.condition = condition
    self.service = service
  def printCarDetail(self):
   print('Name: {} \nYear of manufacture: {} \nList of Services: {},{}'.format(self.name, self.year, self.condition, self.service))

print("No.of Car=", Car.count)
c1 = Car('Lamborghini', 2002)
c1.add_Services('Battery Replacement', 'A/C Recharge')
c2 = Car('Toyota Corolla', 2016)
c2.add_Services('Radiator Flush', 'Fill Service')
c3 = Car('Mitsubishi Pajero', 2018)
c3.add_Services('Filter change', 'Timing Belt Replacement')
print("=========================")
c1.printCarDetail()
print("=========================")
c2.printCarDetail()
print("=========================")
c3.printCarDetail()
print("=========================")
print("No.of Car =", Car.count)
# Out:
# No.of Car= 0
# ...
# Name: Lamborghini
# Year of manufacture: 2002
# List of Services: Battery Replacement,A/C Recharge
# ...
# Name: Toyota Corolla
# Year of manufacture: 2016
# List of Services: Radiator Flush,Fill Service
# ...
# Name: Mitsubishi Pajero
# Year of manufacture: 2018
# List of Services: Filter change,Timing Belt Replacement
# ...
# No.of Car = 3

# %% [markdown]
# 𝗤𝘂𝗲𝘀𝘁𝗶𝗼𝗻:
# Implement the design of the ECustomer​ ​class so that the following output is produced:
# The assumption is E-shopping services cost 200 taka. An e-customer can order any products that cost less than 10000 Taka without any additional delivery charge. If the product’s cost is between 10001 and 50000 taka 5% of the actual cost will be added as delivery charge. If the purchased products cost more than 50000, 10% of the actual cost will be added as delivery charge.
#
# # Write your codes here.
#
# # Do not change the following lines of code.
# print("Total E-Customer:", ECustomer.count)\
# c1 = ECustomer("James")\
# c1.setProductDetails("TV",35000,"Air Cooler", 9000)\
# c2 = ECustomer("Mike")\
# c2.setProductDetails("Mobile",20000,"Headphone", 1200, "Fridge", 45000)\
# c3 = ECustomer("Sarah")\
# c3.setProductDetails("Headphone", 1200)\
# c4 = ECustomer("John")\
# c4.setProductDetails("AC",60000)\
# print("=========================")\
# c1.printDetail()\
# print("=========================")\
# c2.printDetail()\
# print("=========================")\
# c3.printDetail()\
# print("=========================")\
# c4.printDetail()\
# print("=========================")\
# print("Total E-Customer:", ECustomer.count)
#
# Output:
# Total E-Customer: 0\
# =========================\
# Name:   James\
# Total cost with delivery charge: 46410.0\
# =========================\
# Name:   Mike\
# Total cost with delivery charge: 73040.0\
# =========================\
# Name:   Sarah
# Total cost with no delivery charge: 1400.0\
# =========================\
# Name:   John\
# Total cost with delivery charge: 66220.0\
# =========================\
# Total E-Customer: 4

# %%
class ECustomer:
    count=0
    def __init__(self,name):
      self.name=name
      self.items=[]
      self.costs=[]
      ECustomer.count+=1
    def setProductDetails(self,*infos):
      for info in infos:
       if isinstance(info,int)==True:
        self.costs.append(info)
       else:
        self.items.append(info)
    def printDetail(self):
      total=0
      for price in self.costs:
        total+=price
      total+=200
      if total<10000:
       new=float(total)
      elif 10000<total<50000:
       new=total+(0.05*total)
      elif total>50000:
       new=total+(0.1*total)
      print("Name: ",self.name)
      print("Total cost with delivery charge:",new)
# Do not change the following lines of code.
print("Total E-Customer:", ECustomer.count)
c1 = ECustomer("James")
c1.setProductDetails("TV",35000,"Air Cooler", 9000)
c2 = ECustomer("Mike")
c2.setProductDetails("Mobile",20000,"Headphone", 1200, "Fridge", 45000)
c3 = ECustomer("Sarah")
c3.setProductDetails("Headphone", 1200)
c4 = ECustomer("John")
c4.setProductDetails("AC",60000)
print("=========================")
c1.printDetail()
print("=========================")
c2.printDetail()
print("=========================")
c3.printDetail()
print("=========================")
c4.printDetail()
print("=========================")
print("Total E-Customer:", ECustomer.count)
# Out:
# Total E-Customer: 0
# ...
# Name:  James
# Total cost with delivery charge: 46410.0
# ...
# Name:  Mike
# Total cost with delivery charge: 73040.0
# ...
# Name:  Sarah
# Total cost with delivery charge: 1400.0
# ...
# Name:  John
# Total cost with delivery charge: 66220.0
# ...
# Total E-Customer: 4

# %% [markdown]
# 𝗤𝘂𝗲𝘀𝘁𝗶𝗼𝗻:
# Implement the design of the Harry_Potter class so that the following output is produced:
#
# # Write your codes here.
#
# # Do not change the following lines of code.
# print("Book Count:", Harry_Potter.book_count)\
# print("=======================")\
# b1 = Harry_Potter("Harry Potter and the Philosopher's Stone.",1997)\
# print(b1.display_book_info())\
# b2 = Harry_Potter("Harry Potter and the Chamber of Secrets.", 0)\
# b2.set_year(1998)\
# print(b2.display_book_info())\
# b3 = Harry_Potter("Harry Potter and the Prisoner of Azkaban.",1999)\
# print(b3.display_book_info())\
# b4 = Harry_Potter("Default", 0)\
# b4.set_name("Harry Potter and the Goblet of Fire.")\
# b4.set_year(2000)\
# print(b4.display_book_info())\
# print("=======================")\
# print("Book Count:", Harry_Potter.book_count)
#
# Output:\
# Book Count: 0\
# =======================\
# Book---> 1997: Harry Potter and the Philosopher's Stone. \
# Book---> 1998: Harry Potter and the Chamber of Secrets. \
# Book---> 1999: Harry Potter and the Prisoner of Azkaban. \
# Book---> 2000: Harry Potter and the Goblet of Fire. \
# =======================\
# Book Count: 4

# %%
class Harry_Potter:
    book_count = 0

    def __init__(self, name, publish_year):
        self.name = name
        self.publish_year = publish_year
        Harry_Potter.book_count += 1

    def display_book_info(self):
        return 'Book---> ' + str(self.publish_year) + ": " + self.name

    def set_name(self, name):
        self.name = name

    def set_year(self, year):
        self.publish_year = year
 
# Do not change the following lines of code.
print("Book Count:", Harry_Potter.book_count)
print("=======================")
b1 = Harry_Potter("Harry Potter and the Philosopher's Stone.",1997)
print(b1.display_book_info())
b2 = Harry_Potter("Harry Potter and the Chamber of Secrets.", 0)
b2.set_year(1998)
print(b2.display_book_info())
b3 = Harry_Potter("Harry Potter and the Prisoner of Azkaban.",1999)
print(b3.display_book_info())
b4 = Harry_Potter("Default", 0)
b4.set_name("Harry Potter and the Goblet of Fire.")
b4.set_year(2000)
print(b4.display_book_info())
print("=======================")
print("Book Count:", Harry_Potter.book_count)
# Out:
# Book Count: 0
# ...
# Book---> 1997: Harry Potter and the Philosopher's Stone.
# Book---> 1998: Harry Potter and the Chamber of Secrets.
# Book---> 1999: Harry Potter and the Prisoner of Azkaban.
# Book---> 2000: Harry Potter and the Goblet of Fire.
# ...
# Book Count: 4

# %% [markdown]
# 𝗤𝘂𝗲𝘀𝘁𝗶𝗼𝗻:
# Implement the design of the Pizza class so that the following output is produced:
#
# # Write your codes here.
#
# # Do not change the following lines of code.
# print("Pizza Count:", Pizza.pizza_count)   \
# print("=======================")     \
# p1 = Pizza("Chicken")\
# p1.set_toppings_info(25, 1, 4, 0)\
# p1.display()\
# print("------------------------------------")\
# p2 = Pizza("Olives")\
# p2.set_toppings_info(15, 1.5, 0, 0)\
# p2.display()\
# print("------------------------------------")\
# p3 = Pizza("Sausage")\
# p3.set_toppings_info(50, 5, 2, 0)\
# p3.display()\
# print("=======================")\
# print("Pizza Count:", Pizza.pizza_count)
#
# Output:\
# Pizza Count: 0\
# =======================\
# Toppings: Chicken\
# 25  calories\
# 1 g fat\
# 4 g protein\
# ------------------------------------\
# Toppings: Olives\
# 15  calories\
# 1.5 g fat\
# 0 g protein\
# 0 g carbs\
# ------------------------------------\
# Toppings: Sausage\
# 50  calories\
# 5 g fat\
# 2 g protein\
# 0 g carbs\
# =======================\
# Pizza Count: 3

# %%
class Pizza:
  pizza_count = 0
  def __init__(self, type):
    Pizza.pizza_count += 1
    self.type = type
    self.string = ""
  def set_toppings_info(self, cal, fat, pro, carbs):
   self.string = f"Toppings: {self.type}\n{cal} calories\n{fat} g fat\n{pro} g protein\n{carbs} gcarbs"
  def display(self):
   print(f"{self.string}")

print("Pizza Count:", Pizza.pizza_count)
print("=======================")
p1 = Pizza("Chicken")
p1.set_toppings_info(25, 1, 4, 0)
p1.display()
print("------------------------------------")
p2 = Pizza("Olives")
p2.set_toppings_info(15, 1.5, 0, 0)
p2.display()
print("------------------------------------")
p3 = Pizza("Sausage")
p3.set_toppings_info(50, 5, 2, 0)
p3.display()
print("=======================")
print("Pizza Count:", Pizza.pizza_count)
# Out:
# Pizza Count: 0
# ...
# Toppings: Chicken
# 25 calories
# 1 g fat
# 4 g protein
# 0 gcarbs
# ------------------------------------
# Toppings: Olives
# 15 calories
# 1.5 g fat
# 0 g protein
# 0 gcarbs
# ------------------------------------
# Toppings: Sausage
# 50 calories
# 5 g fat
# 2 g protein
# 0 gcarbs
# ...
# Pizza Count: 3

# %%
class Pizza:
    pizza_count=0
    def __init__(self,flav):
      self.flav=flav
      Pizza.pizza_count+=1
    def set_toppings_info(self,cal,fat,prot,carb):
      self.cal=cal
      self.fat=fat
      self.prot=prot
      self.carb=carb
    def display(self):
      print("Toppings:",self.flav)
      print(self.cal,"g","","calories")
      print(self.fat,"g","","fat")
      print(self.prot,"g","","protein")
      print(self.carb,"g","","carbs")
print("Pizza Count:", Pizza.pizza_count)
print("=======================")
p1 = Pizza("Chicken")
p1.set_toppings_info(25, 1, 4, 0)
p1.display()
print("------------------------------------")
p2 = Pizza("Olives")
p2.set_toppings_info(15, 1.5, 0, 0)
p2.display()
print("------------------------------------")
p3 = Pizza("Sausage")
p3.set_toppings_info(50, 5, 2, 0)
p3.display()
print("=======================")
print("Pizza Count:", Pizza.pizza_count)
# Out:
# Pizza Count: 0
# ...
# Toppings: Chicken
# 25 g  calories
# 1 g  fat
# 4 g  protein
# 0 g  carbs
# ------------------------------------
# Toppings: Olives
# 15 g  calories
# 1.5 g  fat
# 0 g  protein
# 0 g  carbs
# ------------------------------------
# Toppings: Sausage
# 50 g  calories
# 5 g  fat
# 2 g  protein
# 0 g  carbs
# ...
# Pizza Count: 3

# %%
class Pizza:
    pizza_count=0
    def __init__(self,name):
      self.name=name
      Pizza.pizza_count+=1
    def set_toppings_info(self,*a):
     self.a=a
    def display(self):
      print("Toppings:", self.name)
      print(self.a[0], "calories")
      print(self.a[1], "g fat")
      print(self.a[2], "g protein")
      print(self.a[3], "g carbs")

# Do not change the following lines of code.
print("Pizza Count:", Pizza.pizza_count)
print("=======================")
p1 = Pizza("Chicken")
p1.set_toppings_info(25, 1, 4, 0)
p1.display()
print("------------------------------------")
p2 = Pizza("Olives")
p2.set_toppings_info(15, 1.5, 0, 0)
p2.display()
print("------------------------------------")
p3 = Pizza("Sausage")
p3.set_toppings_info(50, 5, 2, 0)
p3.display()
print("=======================")
print("Pizza Count:", Pizza.pizza_count)
# Out:
# Pizza Count: 0
# ...
# Toppings: Chicken
# 25 calories
# 1 g fat
# 4 g protein
# 0 g carbs
# ------------------------------------
# Toppings: Olives
# 15 calories
# 1.5 g fat
# 0 g protein
# 0 g carbs
# ------------------------------------
# Toppings: Sausage
# 50 calories
# 5 g fat
# 2 g protein
# 0 g carbs
# ...
# Pizza Count: 3

# %%
class Pizza:
    pizza_count = 0
    def __init__(self, name):
      self.name = name
      self.calories = None
      self.fat = None
      self.protein = None
      self.carbs = None
      Pizza.pizza_count += 1
    def set_toppings_info(self, calories, fat, protein, carbs):
      self.calories = calories
      self.fat = fat
      self.protein = protein
      self.carbs = carbs
    def display(self):
      print(f"Toppings: {self.name}\n{self.calories} calories\n{self.fat} g fat\n{self.protein} g protein\n{self.carbs} g carbs")
print("Pizza Count:", Pizza.pizza_count)
print("=======================")
p1 = Pizza("Chicken")
p1.set_toppings_info(25, 1, 4, 0)
p1.display()
print("------------------------------------")
p2 = Pizza("Olives")
p2.set_toppings_info(15, 1.5, 0, 0)
p2.display()
print("------------------------------------")
p3 = Pizza("Sausage")
p3.set_toppings_info(50, 5, 2, 0)
p3.display()
print("=======================")
print("Pizza Count:", Pizza.pizza_count)
# Out:
# Pizza Count: 0
# ...
# Toppings: Chicken
# 25 calories
# 1 g fat
# 4 g protein
# 0 g carbs
# ------------------------------------
# Toppings: Olives
# 15 calories
# 1.5 g fat
# 0 g protein
# 0 g carbs
# ------------------------------------
# Toppings: Sausage
# 50 calories
# 5 g fat
# 2 g protein
# 0 g carbs
# ...
# Pizza Count: 3
